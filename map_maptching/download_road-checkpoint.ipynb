# %% [markdown]
# # Download road network from OSM

# %%
import osmnx as ox

# %%
ox.config(use_cache=True, log_console=True)

# %%
# shanghai
shanghai_boundary = ox.geocode_to_gdf('shanghai', which_result=2)

# %%
shanghai_boundary
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((120.85086 31.10909, 120.85171 31.107...   31.874617   30.661438
#
#     bbox_east   bbox_west   place_id  osm_type  osm_id        lat        lon  \
# 0  123.334209  120.850858  324704522  relation  913067  31.225299  121.48905
#
#       display_name     class            type  importance
# 0  Shanghai, China  boundary  administrative    0.791123

# %%
shanghai_road = ox.graph_from_place('shanghai',which_result=2, network_type='all')

# %%
shanghai_road.nodes

# %%
shanghai_road.edges

# %%
shanghai_road[2849898496]
# Out:
# AdjacencyView({2849898499: {0: {'osmid': 280965789, 'highway': 'residential', 'oneway': False, 'length': 32.742}}, 2849898483: {0: {'osmid': 280965789, 'highway': 'residential', 'oneway': False, 'length': 76.23400000000001, 'geometry': <shapely.geometry.linestring.LineString object at 0x000001CFC937C0A0>}}, 2849898493: {0: {'osmid': [280965809, 280965811], 'highway': 'residential', 'oneway': False, 'length': 162.024, 'geometry': <shapely.geometry.linestring.LineString object at 0x000001CFC937C310>}}})

# %%
type(shanghai_road[2849898496])
# Out:
# networkx.classes.coreviews.AdjacencyView

# %%
print(shanghai_road[2849898496][2849898493][0]['geometry'])
# Out:
# LINESTRING (121.6359771 31.2212033, 121.6365481 31.2213673, 121.6369344 31.2214628, 121.6372043 31.220911)

# %%
#ox.save_graphml(shanghai_road, filename='shanghai.graphml', folder='./data/osm/shanghai_road')
ox.save_graphml(shanghai_road, filepath='C:/Users/Dilani/Desktop/mapmatching--master/MapMatchingPython/MapMatchingPython/data/osm/shanghai_road/shanghai.graphml', gephi=False, encoding='utf-8')

# %%
ox.basic_stats(shanghai_road)
# Out:
# {'n': 111134,
#  'm': 284357,
#  'k_avg': 5.117371821404791,
#  'edge_length_total': 55117640.959999725,
#  'edge_length_avg': 193.83254486437727,
#  'streets_per_node_avg': 2.9128079615599187,
#  'streets_per_node_counts': {0: 0,
#   1: 19316,
#   2: 385,
#   3: 63006,
#   4: 27621,
#   5: 721,
#   6: 79,
#   7: 3,
#   8: 3},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.17380819551172458,
#   2: 0.003464286357010456,
#   3: 0.5669372109345475,
#   4: 0.24853780121295013,
#   5: 0.00648766354131049,
#   6: 0.0007108535641657818,
#   7: 2.699443914553602e-05,
#   8: 2.699443914553602e-05},
#  'intersection_count': 91818,
#  'street_length_total': 33364190.376999795,
#  'street_segment_count': 161899,
#  'street_length_avg': 206.08027459712412,
#  'circuity_avg': 1.048958648432791,
#  'self_loop_proportion': 0.002174195022822871}

# %%
len(shanghai_road.nodes)
# Out:
# 111134

# %%
len(shanghai_road.edges)
# Out:
# 284357

# %%
import networkx as nx

# %%
#shanghai_road_1 = ox.load_graphml(filename = 'shanghai.graphml', folder = './data/osm/shanghai_road')
shanghai_road_1 = ox.load_graphml(filepath='./data/osm/shanghai_road/shanghai.graphml', node_dtypes=None, edge_dtypes=None, graph_dtypes=None)

# %%
len(shanghai_road_1.nodes)
# Out:
# 111134

# %%
len(shanghai_road_1.edges)
# Out:
# 284357

# %%
ox.plot_graph(shanghai_road_1)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ### Hangzhou

# %%
hangzhou_road = ox.graph_from_place('hangzhou city',which_result=1, network_type='all', simplify=True)

# %%
len(hangzhou_road.nodes)
# Out:
# 92557

# %%
len(hangzhou_road.edges)
# Out:
# 232167

# %%
ox.plot_graph(hangzhou_road)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
#ox.save_graphml(hangzhou_road, filename='hangzhou.graphml', folder='./data/osm/hangzhou_road')
ox.save_graphml(hangzhou_road, filepath='./data/osm/hangzhou_road/hangzhou.graphml', gephi=False, encoding='utf-8')

# %% [markdown]
# ### Nanjing

# %%
nanjing_broder = ox.geocode_to_gdf('nanjing')
nanjing_broder
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  MULTIPOLYGON (((118.33459 31.95435, 118.33469 ...   32.615778   31.230201
#
#     bbox_east   bbox_west   place_id  osm_type   osm_id        lat  \
# 0  119.239507  118.334591  257454456  relation  2131524  31.923156
#
#           lon                  display_name     class            type  \
# 0  118.738533  Nanjing City, Jiangsu, China  boundary  administrative
#
#    importance
# 0    0.732055

# %%
nanjing_road = ox.graph_from_place('nanjing', network_type='all')

# %%
len(nanjing_road.nodes)
# Out:
# 39458

# %%
len(nanjing_road.edges)
# Out:
# 99029

# %%
ox.basic_stats(nanjing_road)
# Out:
# {'n': 39458,
#  'm': 99029,
#  'k_avg': 5.019463733590147,
#  'edge_length_total': 26166257.946000226,
#  'edge_length_avg': 264.22823562794963,
#  'streets_per_node_avg': 2.9759237670434384,
#  'streets_per_node_counts': {0: 0,
#   1: 5653,
#   2: 165,
#   3: 23435,
#   4: 9940,
#   5: 225,
#   6: 34,
#   7: 2,
#   8: 3,
#   9: 1},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.14326625779309646,
#   2: 0.0041816615135080335,
#   3: 0.5939226519337016,
#   4: 0.2519134269349688,
#   5: 0.005702265700238228,
#   6: 0.0008616757058137767,
#   7: 5.068680622433981e-05,
#   8: 7.60302093365097e-05,
#   9: 2.5343403112169904e-05},
#  'intersection_count': 33805,
#  'street_length_total': 16452992.680000061,
#  'street_segment_count': 58495,
#  'street_length_avg': 281.27177844260297,
#  'circuity_avg': 1.0657284083084604,
#  'self_loop_proportion': 0.002051457389520472}

# %%
#ox.save_graphml(nanjing_road, filename='nanjing.graphml', folder='./data/osm/nanjing_road')
ox.save_graphml(nanjing_road, filepath='./data/osm/nanjing_road/nanjing.graphml', gephi=False, encoding='utf-8')

# %%
nanjing_road_utm = ox.project_graph(nanjing_road)

# %%
nanjing_road_utm.graph['crs']
# Out:
# <Projected CRS: +proj=utm +zone=50 +ellps=WGS84 +datum=WGS84 +unit ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 50N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
nanjing_road.graph['crs']
# Out:
# 'epsg:4326'

# %%
ox.plot_graph(nanjing_road)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Porto

# %%
import osmnx as ox
gdf = ox.geocode_to_gdf('porto', which_result=2)

# %%
gdf
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-8.78906 41.41592, -8.78878 41.41540...   41.471972    41.00138
#
#    bbox_east  bbox_west   place_id  osm_type   osm_id        lat       lon  \
# 0  -7.875579  -8.789063  259174500  relation  3459013  41.236688 -8.302018
#
#              display_name     class            type  importance
# 0  Porto, North, Portugal  boundary  administrative    0.613747

# %%
porto_road = ox.graph_from_place('porto', which_result=2, network_type='drive_service')

# %%
# %matplotlib inline
ox.plot_graph(porto_road)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.basic_stats(porto_road)
# Out:
# {'n': 87700,
#  'm': 206648,
#  'k_avg': 4.712611174458381,
#  'edge_length_total': 25768736.107999954,
#  'edge_length_avg': 124.6986958886607,
#  'streets_per_node_avg': 2.656841505131129,
#  'streets_per_node_counts': {0: 0,
#   1: 17799,
#   2: 517,
#   3: 63727,
#   4: 5372,
#   5: 209,
#   6: 75,
#   7: 0,
#   8: 1},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.20295324971493728,
#   2: 0.005895096921322691,
#   3: 0.7266476624857469,
#   4: 0.061254275940706954,
#   5: 0.0023831242873432155,
#   6: 0.0008551881413911061,
#   7: 0.0,
#   8: 1.1402508551881415e-05},
#  'intersection_count': 69901,
#  'street_length_total': 14096298.946000062,
#  'street_segment_count': 116540,
#  'street_length_avg': 120.9567440020599,
#  'circuity_avg': 1.115105751460488,
#  'self_loop_proportion': 0.004410502831645787}

# %%
#ox.save_graphml(porto_road, filename='porto.graphml', folder='./data/osm/porto_road')
ox.save_graphml(porto_road, filepath='./data/osm/porto_road/porto.graphml', gephi=False, encoding='utf-8')
